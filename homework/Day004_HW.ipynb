# %%
import requests
import json

#1. 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11713871592","type":"PullRequestEvent","actor":{"id":54236165,"login":"RockyXDeadman","display_login":"RockyXDeadman","gravatar_id":"","url":"https://api.github.com/users/RockyXDeadman","avatar_url":"https://avatars.githubusercontent.com/u/54236165?"},"repo":{"id":218597365,"name":"Pankaj-Patil22/Games","url":"https://api.github.com/repos/Pankaj-Patil22/Games"},"payload":{"action":"opened","number":1,"pull_request":{"url":"https://api.github.com/repos/Pankaj-Patil22/Games/pulls/1","id":385521070,"node_id":"MDExOlB1bGxSZXF1ZXN0Mzg1NTIxMDcw","html_url":"https://github.com/Pankaj-Patil22/Games/pull/1","diff_url":"https://github.com/Pankaj-Patil22/Games/pull/1.diff","patch_url":"https://github.com/Pankaj-Patil22/Games/pull/1.patch","issue_url":"https://api.github.com/repos/Pankaj-Patil22/Games/issues/1","number":1,"state":"open","locked":false,"title":"pankaj","user":{"login":"RockyXDeadman","id":54236165,"node_id":"MDQ6VXNlcjU0MjM2MTY1","avatar_url":"https://avatars0.githubuser
# ...

# %%
json.loads(r.text)
# Out:
# [{'id': '11713871592',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 54236165,
#    'login': 'RockyXDeadman',
#    'display_login': 'RockyXDeadman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RockyXDeadman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54236165?'},
#   'repo': {'id': 218597365,
#    'name': 'Pankaj-Patil22/Games',
#    'url': 'https://api.github.com/repos/Pankaj-Patil22/Games'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/Pankaj-Patil22/Games/pulls/1',
#     'id': 385521070,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzg1NTIxMDcw',
#     'html_url': 'https://github.com/Pankaj-Patil22/Games/pull/1',
#     'diff_url': 'https://github.com/Pankaj-Patil22/Games/pull/1.diff',
#     'patch_url': 'https://github.com/Pankaj-Patil22/Games/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/Pankaj-Patil22/Games/issues/1',
#     'number': 1,
# ...

# %%
#2. 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
test = requests.get('https://uinames.com/api/?amount=25')
test.text
# Out:
# '[{"name":"Zoltán","surname":"Šimon","gender":"male","region":"Slovakia"},{"name":"Eliana","surname":"Posada","gender":"female","region":"Colombia"},{"name":"Anamaria","surname":"Esinencu","gender":"female","region":"Romania"},{"name":"Sonia","surname":"Benga","gender":"female","region":"Romania"},{"name":"Victoria","surname":"Paquette","gender":"female","region":"Canada"},{"name":"Aidan","surname":"Goodwin","gender":"male","region":"New Zealand"},{"name":"Dumitrana","surname":"Bîrlădeanu","gender":"female","region":"Romania"},{"name":"Cornelia","surname":"Lăzăreanu","gender":"female","region":"Romania"},{"name":"Petre","surname":"Hălmăgeanu","gender":"male","region":"Romania"},{"name":"Cecilia","surname":"Breban","gender":"female","region":"Romania"},{"name":"Sorina","surname":"Gligor","gender":"female","region":"Romania"},{"name":"Lenka","surname":"Pavka","gender":"female","region":"Slovakia"},{"name":"Savina","surname":"Toderaș","gender":"female","region":"Romania"},{"name":"Paige
# ...

# %%
json.loads(test.text)[0]
# Out:
# {'name': 'Zoltán', 'surname': 'Šimon', 'gender': 'male', 'region': 'Slovakia'}
